# %% [markdown]
# # 04. Modelagem com Árvore de Decisão
#
# Este notebook é dedicado ao desenvolvimento, otimização de hiperparâmetros e avaliação do modelo baseado em Árvore de Decisão (Scikit-Learn).

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
