# %% [markdown]
# # 05. Comparação Final dos Modelos
#
# Este notebook consolida as métricas obtidas pelos modelos de Rede Neural e Árvore de Decisão (Acurácia, Precisão, Recall, F1-Score, Curva ROC/AUC) e apresenta a comparação e conclusões finais.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
